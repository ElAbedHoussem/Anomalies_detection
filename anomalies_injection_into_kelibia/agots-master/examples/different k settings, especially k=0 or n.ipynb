# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from agots.multivariate_generators.multivariate_data_generator import MultivariateDataGenerator

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 1
K = 0

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#      x0
# x0  1.0

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 1
K = 1

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#      x0
# x0  1.0

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 2
K = 1

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#           x0        x1
# x0  1.000000 -0.056126
# x1 -0.056126  1.000000

# %%
np.random.seed(1337)

STREAM_LENGTH = 200
N = 2
K = 2

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#           x0        x1
# x0  1.000000  0.993202
# x1  0.993202  1.000000
