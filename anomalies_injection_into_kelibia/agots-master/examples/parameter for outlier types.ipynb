# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from agots.multivariate_generators.multivariate_data_generator import MultivariateDataGenerator

# %%
np.random.seed(1337)

STREAM_LENGTH = 30
N = 4
K = 2

dg = MultivariateDataGenerator(STREAM_LENGTH, N, K)
df = dg.generate_baseline(initial_value_min=-4, initial_value_max=4)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
# Out:
#           x0        x1        x2        x3
# x0  1.000000  0.966288  0.954230  0.959614
# x1  0.966288  1.000000  0.989372  0.991661
# x2  0.954230  0.989372  1.000000  0.995696
# x3  0.959614  0.991661  0.995696  1.000000

# %%
df = dg.add_outliers({'extreme': [{'n': 0, 'timestamps': [(5,), (19,)],
                                   'value': 1
                                  }],
                      'shift':   [{'n': 1, 'timestamps': [(10, 19)],
                                   'value': -20  # or 'value' (for a plain addition)
                                  }],
                      'trend':   [{'n': 2, 'timestamps': [(2, 15)],
                                   'value': 0.15
                                  }],
                      'variance':[{'n': 3, 'timestamps': [(2, 8)],
                                   'value': 19
                                  }]})

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()
df
# Out:
# extreme
# shift
# trend
# variance
#           x0         x1   x2        x3
# 0   3.000000   0.000000  0.0  0.000000
# 1   1.572558   0.000000  0.0  0.000000
# 2   1.873181   0.000000  0.0 -6.820255
# 3   1.361140   0.000000 -0.8  1.729813
# 4   1.408475   0.000000 -1.6 -1.916899
# 5   0.010774   0.000000 -2.4  0.573755
# 6   0.471416   0.000000 -3.2  0.402771
# 7  -0.755087   0.000000 -4.0 -3.077173
# 8  -1.636673   0.000000 -4.8  0.000000
# 9  -0.663525   0.000000 -5.6  0.000000
# 10 -1.283220  12.286015 -6.4  0.000000
# 11 -1.536990  12.286015 -7.2  0.000000
# 12 -2.287679  12.286015 -8.0  0.000000
# 13 -2.983284  12.286015 -8.8  0.000000
# 14 -2.489979  12.286015 -9.6  0.000000
# 15 -2.149973  12.286015 -9.6  0.000000
# 16 -1.724639  12.286015 -9.6  0.000000
# 17 -1.737808  12.286015 -9.6  0.000000
# 18 -1.916642  12.286015 -9.6  0.000000
# 19  0.814765   0.000000 -9.6  0.000000
# 20 -3.861418   0.000000 -9.6  0.000000
# 21 -4.286052   0.000000 -9.6  0.000000
# 22 -6.552661   0.000000 -9.6  0.000000
# 23 -6.822826   0.000000 -9.6  0.000000
# 24 -5.788658   0.000000 -9.6  0.000000
# 25 -6.900170   0.000000 -9.6  0.000000
# 26 -7.084310   0.000000 -9.6  0.000000
# 27 -6.900403   0.000000 -9.6  0.000000
# 28 -6.241356   0.000000 -9.6  0.000000
# 29 -5.662134   0.000000 -9.6  0.000000

# %%
np.random.seed(1337)



dg = MultivariateDataGeneratorFromDF(STREAM_LENGTH, N, K)

for col in df.columns:
    plt.plot(df[col], label=col)
plt.legend()
plt.show()

df.corr()
